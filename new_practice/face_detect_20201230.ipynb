# %% [markdown]
# <a href="https://colab.research.google.com/github/jinwoongokRe/AI_basic_study/blob/master/new_practice/face_detect_20201230.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2

#캐스케이드 파일 지정해서 검출기 생성하기(*1)

# %%
cascade_file = '/content/drive/MyDrive/haarcascade_frontalface_alt.xml'
cascade = cv2.CascadeClassifier(cascade_file)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
#이미지를 읽어 들이고 그레이 스케일로 변환하기(*2)
img = cv2.imread('/content/drive/MyDrive/IMG_8909.JPG')

# %%
plt.imshow(img)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray
# Out:
# array([[107, 119,  90, ...,  91,  79,  80],
#        [108, 108,  65, ...,  78,  59,  78],
#        [104, 126, 121, ...,  87,  81,  67],
#        ...,
#        [216, 213, 212, ..., 208, 207, 203],
#        [209, 210, 204, ..., 205, 207, 210],
#        [204, 209, 202, ..., 204, 203, 206]], dtype=uint8)

# %%
plt.imshow(img_gray)

# %%
#얼굴 인식하기(*3)
face_list = cascade.detectMultiScale(img_gray, minSize=(150, 150)) #얼굴검출 실행, 메서드를 사용함. 첫 번째 매개변수로 그레이 스케일 이미지 데이터를 전달하고 두번째 매개변수로 키워드 매개변수를 활용해 minSize를 지정함. 이는 얼굴 인식 영역의 최소크기를 지정하는 것.
#결과 확인하기(*4)
if len(face_list) ==0:
  print("실패")
  quit()

#인식한 부분 표시하기 (*5)
for(x,y,w,h) in face_list:
  print("얼굴의 좌표 =", x,y,w,h)
  red = (0,0, 255)
  cv2.rectangle(img, (x,y), (x+w, y+h), red, thickness=20)
# Out:
# 얼굴의 좌표 = 32 166 2037 2037

# %%
# 이미지 출력하기
cv2.imwrite("face-detect.png", img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
